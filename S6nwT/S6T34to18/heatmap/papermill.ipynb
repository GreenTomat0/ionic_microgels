# %%
# %%bash
# $ conda activate myenv
# $ python3 -m ipykernel install --user --name myenv

# %%
# !pip install matplotlib
# !pip install PIMS
# !pip install trackpy
# !numpy==1.26.4
# !pip install pandas==1.5.3
# !pip install opencv-python
# !pip install plotly

# %%
import papermill as pm

# %%
parameters = [
{
    "sample": 4,
    "series": 0,
    "subarea": 1
}, {
    "sample": 4,
    "series": 0,
    "subarea": 2
}, {
    "sample": 4,
    "series": 0,
    "subarea": 3
}, {
    "sample": 4,
    "series": 0,
    "subarea": 4
}, {
    "sample": 4,
    "series": 0,
    "subarea": 5
}, {
    "sample": 4,
    "series": 0,
    "subarea": 6
}, {
    "sample": 4,
    "series": 0,
    "subarea": 7
}, {
    "sample": 4,
    "series": 0,
    "subarea": 8
}, 
{
    "sample": 4,
    "series": 1000,
    "subarea": 1
}, {
    "sample": 4,
    "series": 1000,
    "subarea": 2
}, {
    "sample": 4,
    "series": 1000,
    "subarea": 3
}, {
    "sample": 4,
    "series": 1000,
    "subarea": 4
}, {
    "sample": 4,
    "series": 1000,
    "subarea": 5
}, {
    "sample": 4,
    "series": 1000,
    "subarea": 6
}, {
    "sample": 4,
    "series": 1000,
    "subarea": 7
}, {
    "sample": 4,
    "series": 1000,
    "subarea": 8
}, 
{
    "sample": 4,
    "series": 2000,
    "subarea": 1
}, {
    "sample": 4,
    "series": 2000,
    "subarea": 2
}, {
    "sample": 4,
    "series": 2000,
    "subarea": 3
}, {
    "sample": 4,
    "series": 2000,
    "subarea": 4
}, {
    "sample": 4,
    "series": 2000,
    "subarea": 5
}, {
    "sample": 4,
    "series": 2000,
    "subarea": 6
}, {
    "sample": 4,
    "series": 2000,
    "subarea": 7
}, {
    "sample": 4,
    "series": 2000,
    "subarea": 8
}, 
{
    "sample": 4,
    "series": 3000,
    "subarea": 1
}, {
    "sample": 4,
    "series": 3000,
    "subarea": 2
}, {
    "sample": 4,
    "series": 3000,
    "subarea": 3
}, {
    "sample": 4,
    "series": 3000,
    "subarea": 4
}, {
    "sample": 4,
    "series": 3000,
    "subarea": 5
}, {
    "sample": 4,
    "series": 3000,
    "subarea": 6
}, {
    "sample": 4,
    "series": 3000,
    "subarea": 7
}, {
    "sample": 4,
    "series": 3000,
    "subarea": 8
}, 
{
    "sample": 4,
    "series": 4000,
    "subarea": 1
}, {
    "sample": 4,
    "series": 4000,
    "subarea": 2
}, {
    "sample": 4,
    "series": 4000,
    "subarea": 3
}, {
    "sample": 4,
    "series": 4000,
    "subarea": 4
}, {
    "sample": 4,
    "series": 4000,
    "subarea": 5
}, {
    "sample": 4,
    "series": 4000,
    "subarea": 6
}, {
    "sample": 4,
    "series": 4000,
    "subarea": 7
}, {
    "sample": 4,
    "series": 4000,
    "subarea": 8
}, 
# {
#     "sample": 4,
#     "series": 5000,
#     "subarea": 1
# }, {
#     "sample": 4,
#     "series": 5000,
#     "subarea": 2
# }, {
#     "sample": 4,
#     "series": 5000,
#     "subarea": 3
# }, {
#     "sample": 4,
#     "series": 5000,
#     "subarea": 4
# }, {
#     "sample": 4,
#     "series": 5000,
#     "subarea": 5
# }, {
#     "sample": 4,
#     "series": 5000,
#     "subarea": 6
# }, {
#     "sample": 4,
#     "series": 5000,
#     "subarea": 7
# }, {
#     "sample": 4,
#     "series": 5000,
#     "subarea": 8
# }, 
# {
#     "sample": 4,
#     "series": 6000,
#     "subarea": 1
# }, {
#     "sample": 4,
#     "series": 6000,
#     "subarea": 2
# }, {
#     "sample": 4,
#     "series": 6000,
#     "subarea": 3
# }, {
#     "sample": 4,
#     "series": 6000,
#     "subarea": 4
# }, {
#     "sample": 4,
#     "series": 6000,
#     "subarea": 5
# }, {
#     "sample": 4,
#     "series": 6000,
#     "subarea": 6
# }, {
#     "sample": 4,
#     "series": 6000,
#     "subarea": 7
# }, {
#     "sample": 4,
#     "series": 6000,
#     "subarea": 8
# }, 
# {
#     "sample": 4,
#     "series": 7000,
#     "subarea": 1
# }, {
#     "sample": 4,
#     "series": 7000,
#     "subarea": 2
# }, {
#     "sample": 4,
#     "series": 7000,
#     "subarea": 3
# }, {
#     "sample": 4,
#     "series": 7000,
#     "subarea": 4
# }, {
#     "sample": 4,
#     "series": 7000,
#     "subarea": 5
# }, {
#     "sample": 4,
#     "series": 7000,
#     "subarea": 6
# }, {
#     "sample": 4,
#     "series": 7000,
#     "subarea": 7
# }, {
#     "sample": 4,
#     "series": 7000,
#     "subarea": 8
# }, 
{
    "sample": 5,
    "series": 0,
    "subarea": 1
}, {
    "sample": 5,
    "series": 0,
    "subarea": 2
}, {
    "sample": 5,
    "series": 0,
    "subarea": 3
}, {
    "sample": 5,
    "series": 0,
    "subarea": 4
}, {
    "sample": 5,
    "series": 0,
    "subarea": 5
}, {
    "sample": 5,
    "series": 0,
    "subarea": 6
}, {
    "sample": 5,
    "series": 0,
    "subarea": 7
}, {
    "sample": 5,
    "series": 0,
    "subarea": 8
}, 
{
    "sample": 5,
    "series": 1000,
    "subarea": 1
}, {
    "sample": 5,
    "series": 1000,
    "subarea": 2
}, {
    "sample": 5,
    "series": 1000,
    "subarea": 3
}, {
    "sample": 5,
    "series": 1000,
    "subarea": 4
}, {
    "sample": 5,
    "series": 1000,
    "subarea": 5
}, {
    "sample": 5,
    "series": 1000,
    "subarea": 6
}, {
    "sample": 5,
    "series": 1000,
    "subarea": 7
}, {
    "sample": 5,
    "series": 1000,
    "subarea": 8
}, 
{
    "sample": 5,
    "series": 2000,
    "subarea": 1
}, {
    "sample": 5,
    "series": 2000,
    "subarea": 2
}, {
    "sample": 5,
    "series": 2000,
    "subarea": 3
}, {
    "sample": 5,
    "series": 2000,
    "subarea": 4
}, {
    "sample": 5,
    "series": 2000,
    "subarea": 5
}, {
    "sample": 5,
    "series": 2000,
    "subarea": 6
}, {
    "sample": 5,
    "series": 2000,
    "subarea": 7
}, {
    "sample": 5,
    "series": 2000,
    "subarea": 8
}, 
{
    "sample": 5,
    "series": 3000,
    "subarea": 1
}, {
    "sample": 5,
    "series": 3000,
    "subarea": 2
}, {
    "sample": 5,
    "series": 3000,
    "subarea": 3
}, {
    "sample": 5,
    "series": 3000,
    "subarea": 4
}, {
    "sample": 5,
    "series": 3000,
    "subarea": 5
}, {
    "sample": 5,
    "series": 3000,
    "subarea": 6
}, {
    "sample": 5,
    "series": 3000,
    "subarea": 7
}, {
    "sample": 5,
    "series": 3000,
    "subarea": 8
}, 
{
    "sample": 5,
    "series": 4000,
    "subarea": 1
}, {
    "sample": 5,
    "series": 4000,
    "subarea": 2
}, {
    "sample": 5,
    "series": 4000,
    "subarea": 3
}, {
    "sample": 5,
    "series": 4000,
    "subarea": 4
}, {
    "sample": 5,
    "series": 4000,
    "subarea": 5
}, {
    "sample": 5,
    "series": 4000,
    "subarea": 6
}, {
    "sample": 5,
    "series": 4000,
    "subarea": 7
}, {
    "sample": 5,
    "series": 4000,
    "subarea": 8
},
]

for params in parameters:
    pm.execute_notebook(
        "heatmap_pretrained.ipynb",
        f"data_out/output_{params['sample']}_{params['series']}_{params['subarea']}.ipynb",
        kernel_name="myenv",
        parameters=params
    )
